# %% [markdown]
# NIM       : 20.83.0533
#
# Nama      : Rina Setiani

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = ("/content/drive/MyDrive/MACHINE LEARNING/Data")

# %%
df = pd.read_csv(path+"/House Time Construction.csv")
df
# Out:
#     1200  1  3  1.1  1.2   90
# 0   1300  2  3    0    1  100
# 1   1400  1  3    0    0   80
# 2   1500  2  4    1    1   90
# 3   1550  1  3    0    0   80
# 4   1600  1  3    1    0   85
# 5   1650  2  4    0    0  110
# 6   1650  1  3    1    0   85
# 7   1700  1  3    0    0   95
# 8   1750  1  3    1    0   90
# 9   1800  1  3    0    0   95
# 10  1850  1  3    1    0  100
# 11  1900  2  4    0    1  110
# 12  1950  1  3    0    1  105
# 13  2000  2  4    0    1  120
# 14  2050  2  4    1    1  130
# 15  2100  2  4    1    1  125
# 16  2100  1  4    1    1  115
# 17  2200  2  4    1    0  130
# 18  2250  2  4    0    0  120
# 19  2300  2  5    1    0  140
# 20  2350  2  5    1    0  135
# 21  2400  2  4    0    1  125
# 22  2450  2  4    1    1  145
# 23  2500  2  5    1    1  150
# 24  2550  2  4    1    1  135
# 25  2600  2  5    1    1  150
# 26  2700  2  5    1    1  160
# 27  2750  2  4    1    1  155
# 28  2800  2  5    1    1  150

# %%
nama_kolom = ['Ukuran', 'Jumlah Lantai', 'Jumlah Kamar', 'Lokasi', 'Jenis Bahan', 'Waktu']

df.columns = nama_kolom

pd.set_option('display.max_columns', 10)
df
# Out:
#     Ukuran  Jumlah Lantai  Jumlah Kamar  Lokasi  Jenis Bahan  Waktu
# 0     1300              2             3       0            1    100
# 1     1400              1             3       0            0     80
# 2     1500              2             4       1            1     90
# 3     1550              1             3       0            0     80
# 4     1600              1             3       1            0     85
# 5     1650              2             4       0            0    110
# 6     1650              1             3       1            0     85
# 7     1700              1             3       0            0     95
# 8     1750              1             3       1            0     90
# 9     1800              1             3       0            0     95
# 10    1850              1             3       1            0    100
# 11    1900              2             4       0            1    110
# 12    1950              1             3       0            1    105
# ...

# %%
np.random.seed(42)
split = np.random.rand(len(df)) < 0.8
train = df[split]
test = df[~split]

# %%
X_train = np.asanyarray(train[['Ukuran']])
y_train = np.asanyarray(train[['Waktu']])

X_test = np.asanyarray(test[['Ukuran']])
y_test = np.asanyarray(test[['Waktu']])

# %%
from sklearn.linear_model import LinearRegression

lr_model = LinearRegression()
lr_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print ('Coefficients: ', lr_model.coef_)
print ('Intercept: ', lr_model.intercept_)
# Out:
# Coefficients:  [[0.05286034]]
# Intercept:  [9.26469274]

# %%
plt.scatter(X_train, y_train,  color='blue')
plt.plot(X_train, lr_model.coef_[0][0]*X_train + lr_model.intercept_[0], '-r')
plt.xlabel('Ukuran')
plt.ylabel('Waktu')
# Out:
# Text(0, 0.5, 'Waktu')

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

print("R2-score: %.2f" % r2_score(y_pred, y_test))
print('Mean Absolute Error (MAE): %.2f' % mean_absolute_error(y_pred, y_test))
print('Mean Squared Error (MSE): %.2f' % mean_squared_error(y_pred, y_test))
# Out:
# R2-score: 0.84
# Mean Absolute Error (MAE): 3.76
# Mean Squared Error (MSE): 20.43
